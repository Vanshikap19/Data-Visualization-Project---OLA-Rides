# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
data = pd.read_csv('Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 33 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Date                                                   675 non-null    object
#  1   Day of the Week                                        675 non-null    object
#  2   Start Time(Hours)                                      675 non-null    object
#  3   Chatrapati Shivaji (International) Fare                661 non-null    float64
#  4   Kokilaben Hospital Fare                                656 non-null    float64
#  5   Bank of Baroda(BKC) Fare                               652 non-null    float64
#  6   Marine Drive Aquarium Fare                             660 non-null    float64
#  7   Phoenix Mall Fare                                      662 non-null    float64
# ...

# %%
data.describe()
# Out:
#        Chatrapati Shivaji (International) Fare  Kokilaben Hospital Fare  \
# count                               661.000000               656.000000
# mean                                260.119516               355.618902
# std                                 105.066743               192.311114
# min                                 117.000000               181.000000
# 25%                                 183.000000               252.500000
# 50%                                 239.000000               308.000000
# 75%                                 316.000000               401.250000
# max                                 918.000000              3661.000000
#
#        Bank of Baroda(BKC) Fare  Marine Drive Aquarium Fare  \
# count                652.000000                  660.000000
# mean                 396.363497                  693.860606
# std                  173.135975                  256.776779
# min                  199.000000                  353.000000
# ...

# %%
data.head()
# Out:
#          Date Day of the Week Start Time(Hours)  \
# 0  28-09-2021         Tuesday              8:00
# 1  28-09-2021         Tuesday              8:00
# 2  28-09-2021         Tuesday              8:00
# 3  28-09-2021         Tuesday              9:00
# 4  28-09-2021         Tuesday              9:00
#
#    Chatrapati Shivaji (International) Fare  Kokilaben Hospital Fare  \
# 0                                    144.0                    202.0
# 1                                    187.0                    262.0
# 2                                    270.0                    373.0
# 3                                    257.0                    220.0
# 4                                    333.0                    283.0
#
#    Bank of Baroda(BKC) Fare  Marine Drive Aquarium Fare  Phoenix Mall Fare  \
# 0                     223.0                       424.0              155.0
# 1                     290.0                       549.0              202.0
# ...

# %%
sns.distplot(data['Chatrapati Shivaji (International) Fare'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Chatrapati Shivaji (International) Fare', ylabel='Density'>

# %%
sns.jointplot(x='Chatrapati Shivaji (International) Fare', y='Chhatrapati Airport(International)Travel Time',data=data)

# %%
sns.jointplot(x='Bank of Baroda(BKC) Fare', y='Bank of Baroda BKC Travel Time',data=data)

# %%
sns.jointplot(x='Kokilaben Hospital Fare', y='Kokilaben Hospital Travel Time',data=data)

# %%
sns.jointplot(x='Marine Drive Aquarium Fare', y='Marine Drive Travel Time',data=data)

# %%
sns.jointplot(x='Phoenix Mall Fare', y='Phoenix Mall Travel Time',data=data)

# %%
sns.boxplot(x='Chatrapati Shivaji (International) Fare',y='Type of Car',data=data)
# Out:
# <AxesSubplot:xlabel='Chatrapati Shivaji (International) Fare', ylabel='Type of Car'>

# %%
sns.boxplot(x='Kokilaben Hospital Fare',y='Type of Car',data=data)
# Out:
# <AxesSubplot:xlabel='Kokilaben Hospital Fare', ylabel='Type of Car'>

# %%
sns.boxplot(x='Bank of Baroda(BKC) Fare',y='Type of Car',data=data)
# Out:
# <AxesSubplot:xlabel='Bank of Baroda(BKC) Fare', ylabel='Type of Car'>

# %%
sns.boxplot(x='Marine Drive Aquarium Fare',y='Type of Car',data=data)
# Out:
# <AxesSubplot:xlabel='Marine Drive Aquarium Fare', ylabel='Type of Car'>

# %%
sns.boxplot(x='Phoenix Mall Fare',y='Type of Car',data=data)
# Out:
# <AxesSubplot:xlabel='Phoenix Mall Fare', ylabel='Type of Car'>

# %%
sns.heatmap(data.isnull(),cbar = False, cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
sns.countplot(x='Holiday/Festival',data=data)
# Out:
# <AxesSubplot:xlabel='Holiday/Festival', ylabel='count'>

# %%
sns.countplot('Number of Cars Nearby',data=data)
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Number of Cars Nearby', ylabel='count'>
